# %% [markdown]
# Notebook Setup

# %%
#import dependencies
import requests
from pprint import pprint
from requests.auth import HTTPBasicAuth
import pandas as pd

#authentication flow
client_id = "4b454f446d1f479082eec9de1c27a4a8"
client_secret = "e639450422594948b17c46d1a82f4882"

url = "https://accounts.spotify.com/api/token?grant_type=client_credentials"
headers = {'content-type': 'application/x-www-form-urlencoded'}

try:
   response = requests.post(url, headers=headers, auth=(client_id, client_secret))
   json = response.json()
   print(json)
   access_token = json["access_token"]
   print(access_token)
except:
   print("Something went wrong with the request")
# Out:
# {'access_token': 'BQAs6Nv-Iih3RmWyLVfTrRVGIXxGQCca7qsssfTKAFiIro5iIhjvzKwCPe0GNzLttfFqD5nMUh9kbvgu55A', 'token_type': 'Bearer', 'expires_in': 3600, 'scope': ''}
# BQAs6Nv-Iih3RmWyLVfTrRVGIXxGQCca7qsssfTKAFiIro5iIhjvzKwCPe0GNzLttfFqD5nMUh9kbvgu55A

# %% [markdown]
# Collect Data

# %%
# https://api.spotify.com/v1/artists/{id}

#This is for US Top 50 playlist
playlist_id = "37i9dQZEVXbLRQDuF5jeBp"
#spotify:user:spotifycharts:playlist:37i9dQZEVXbLRQDuF5jeBp

url = f"https://api.spotify.com/v1/playlists/{playlist_id}"

headers = {'authorization': f"Bearer {access_token}"}
response = requests.get(url, headers=headers)

#pprint(response.json())
#print(json.dumps(newrelease, sort_keys=True, indent=4))
jj = response.json()
#pprint(jj)

# %%
#test check: to grab album uri
#jj['tracks']['items'][0]['track']['album']['uri'][14:])
#test check to grab artist uri
pprint(jj['tracks']['items'][0]['track']['album']['artists'][0]["uri"][15:])
# Out:
# '66CXWjxzNUsdJxJ2JdwvnR'

# %%
songs= jj['tracks']['items']

# %%
#Create lists for relevant data & then organize into a dataframe
ids = []
artists = []
tracks = []
releasedate = []
audiofeatures = []
popularity = []
for x in songs:
    idsong = x["track"]["id"]
    ids.append(idsong)
    artist = x['track']['album']['artists'][0]['name']
    artists.append(artist)
    track = x['track']['name']
    tracks.append(track)
    rd = x["track"]["album"]["release_date"]
    releasedate.append(rd)
    poppin = x['track']['popularity']
    popularity.append(poppin)
    url = f"https://api.spotify.com/v1/audio-features/{idsong}"
    headers = {'authorization': f"Bearer {access_token}"}
    response = requests.get(url, headers=headers)
    features= response.json()
    audiofeatures.append(features)
#pprint(features)

# %%
#looking for genre of each artist via for loop
artid = []
genre = []
for x in songs:
    ida = x['track']['album']['artists'][0]["uri"][15:]
    artid.append(ida)
    url = f"https://api.spotify.com/v1/artists/{ida}"
    headers = {'authorization': f"Bearer {access_token}"}
    response = requests.get(url, headers=headers)
    gen= response.json()
    genr = gen["genres"]
    genre.append(genr)

# %%
# Out:
# [['dance pop', 'pop', 'post-teen pop'], ['dance pop', 'pop', 'post-teen pop'], ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'], ['pop', 'rap'], [], ['chicago rap'], ['rap', 'trap music'], ['hip hop', 'philly rap', 'pop', 'pop rap', 'rap', 'trap music'], ['atl hip hop', 'pop', 'pop rap', 'rap', 'trap music'], ['cali rap', 'rap', 'trap music'], ['dance pop', 'pop', 'post-teen pop'], ['pop'], ['atl hip hop', 'atl trap', 'rap', 'trap music'], ['dance pop', 'pop', 'post-teen pop'], ['electropop', 'pop'], ['dance pop', 'pop', 'post-teen pop'], ['dance pop', 'pop', 'post-teen pop'], ['pop', 'rap'], ['cali rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music'], ['pop', 'rap'], ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop'], ['rap', 'trap music'], ['rap', 'trap music'], ['miami hip hop', 'pop rap', 'rap', 'trap music'], ['dance pop', 'pop', 'post-teen pop'], ['brostep', 'egyptian pop', 'progressive electro house'], ['dance pop', 'pop', 'post-teen pop'], ['hip hop', 'pop rap', 'rap', 'trap music', 'underground hip hop', 'vapor trap'], ['dance pop', 'pop', 'post-teen pop'], ['dance pop', 'pop', 'post-teen pop'], ['pop'], ['atl hip hop', 'rap', 'trap music'], ['dance pop', 'pop', 'post-teen pop'], ['chicago rap'], ['rap', 'trap music', 'underground hip hop', 'vapor trap'], ['chicago rap'], ['pop', 'rap'], ['atl hip hop', 'dirty south rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music'], ['dance pop', 'electropop', 'pop', 'tropical house'], ['pop'], ['pop', 'rap'], ['atl hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music'], ['emo rap', 'miami hip hop'], ['dance pop', 'pop', 'post-teen pop'], ['hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music'], ['dance pop', 'pop'], ['british indie rock', 'modern alternative rock', 'modern rock'], ['dance pop', 'pop', 'post-teen pop', 'r&b', 'rap'], ['rap', 'trap music'], ['dance pop', 'edm', 'electropop', 'pop', 'tropical house']]

# %%
#separate the dictionary into lists
afkeys = [list(x.keys()) for x in audiofeatures]
afvalues = [list(x.values()) for x in audiofeatures]

#create a dataframe for audio features
af = pd.DataFrame(afvalues, columns=afkeys[0])
#create a dataframe for track info
tdata = pd.DataFrame(list(zip(tracks, artists, releasedate, popularity, genre)),columns=["tracks", "artists","released", "popularity", "genre"])

# %%
tdata.head()
# Out:
#                                           tracks          artists    released  \
# 0                                        7 rings    Ariana Grande  2019-02-08
# 1       break up with your girlfriend, i'm bored    Ariana Grande  2019-02-08
# 2                                   MIDDLE CHILD          J. Cole  2019-01-23
# 3                                           Wow.      Post Malone  2018-12-24
# 4  Sunflower - Spider-Man: Into the Spider-Verse  Various Artists  2018-12-14
#
#    popularity                                              genre
# 0          91                    [dance pop, pop, post-teen pop]
# 1          96                    [dance pop, pop, post-teen pop]
# 2          94  [conscious hip hop, nc hip hop, pop, pop rap, ...
# 3          98                                         [pop, rap]
# 4          98                                                 []

# %%
#combine the two dataframes 
data = pd.concat([tdata, af], axis=1, sort=False)

#clean data by removing unneccesary columns
data.drop(["uri", "track_href", "analysis_url"],axis = 1, inplace = True)
data
# Out:
#                                            tracks                 artists  \
# 11  2019-02-07          89                                              [pop]
# 12  2018-10-05          90           [atl hip hop, atl trap, rap, trap music]
# 13  2018-02-07          71                    [dance pop, pop, post-teen pop]
# 14  2019-01-30          95                                  [electropop, pop]
# 15  2019-02-08          91                    [dance pop, pop, post-teen pop]
# 16  2018-02-07          69                    [dance pop, pop, post-teen pop]
# 17  2018-08-03          94                                         [pop, rap]
# 18  2019-01-16          87  [cali rap, hip hop, pop, pop rap, rap, souther...
# 19  2019-02-15          84                                         [pop, rap]
# 20  2018-10-04          97  [dance pop, electropop, etherpop, indie poptim...
# 21  2018-12-21          90                                  [rap, trap music]
# 22  2018-12-21          88                                  [rap, trap music]
# 23  2018-12-14          92          [miami hip hop, pop rap, rap, trap music]
# 24  2019-02-08          90                    [dance pop, pop, post-teen pop]
# 25  2018-08-17          96  [brostep, egyptian pop, progressive electro ho...
# 26  2019-01-24          91                    [dance pop, pop, post-teen pop]
# 27  2018-10-05          91  [hip hop, pop rap, rap, trap music, undergroun...
# 28  2019-02-08          88                    [dance pop, pop, post-teen pop]
# 29  2019-02-08          89                    [dance pop, pop, post-teen pop]
# 30  2019-01-11          95                                              [pop]
# 31  2019-02-14          80                     [atl hip hop, rap, trap music]
# 32  2018-02-07          65                    [dance pop, pop, post-teen pop]
# 33  2018-12-10          90                                      [chicago rap]
# 34  2018-09-04          90  [rap, trap music, underground hip hop, vapor t...
# 35  2018-12-10          87                                      [chicago rap]
# 36  2018-10-23          88                                         [pop, rap]
# 37  2018-12-07          79  [atl hip hop, dirty south rap, hip hop, pop, p...
# 38  2018-12-07          82       [dance pop, electropop, pop, tropical house]
# 39  2018-10-18          86                                              [pop]
# 40  2018-04-27          92                                         [pop, rap]
# 41  2018-12-04          87  [atl hip hop, hip hop, pop, pop rap, rap, sout...
# 42  2018-03-16          91                           [emo rap, miami hip hop]
# 43  2019-02-08          87                    [dance pop, pop, post-teen pop]
# 44  2018-11-06          86  [hip hop, pop, pop rap, rap, southern hip hop,...
# 45  2018-10-05          92                                   [dance pop, pop]
# 46  2019-02-14          80  [british indie rock, modern alternative rock, ...
# 47  2019-01-10          89          [dance pop, pop, post-teen pop, r&b, rap]
# 48  2018-12-21          79                                  [rap, trap music]
# 49  2019-02-07          87  [dance pop, edm, electropop, pop, tropical house]
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.771   0.320    1   -10.752     0       0.3160       0.60100
# 1          0.726   0.545    5    -5.489     0       0.1020       0.03780
# 2          0.837   0.364    8   -11.713     1       0.2760       0.14900
# 3          0.833   0.539   11    -7.399     0       0.1780       0.16300
# 4          0.760   0.479    2    -5.574     1       0.0466       0.55600
# 5          0.708   0.691    2    -5.179     1       0.0442       0.34200
# 6          0.759   0.730    0    -7.985     0       0.0516       0.14500
# 7          0.889   0.496    4    -6.365     0       0.0905       0.25900
# 8          0.837   0.636    1    -7.643     1       0.0860       0.03950
# 9          0.906   0.382   10   -12.890     0       0.2690       0.18000
# 9           0.000000    0.1130    0.391  104.025  audio_features
# 10          0.000000    0.1020    0.402  107.016  audio_features
# 11          0.000000    0.0876    0.338  136.001  audio_features
# 12          0.000000    0.5520    0.358  112.502  audio_features
# 13          0.000000    0.2530    0.542   74.972  audio_features
# 14          0.162000    0.1060    0.196  120.046  audio_features
# 15          0.000003    0.2010    0.169   86.990  audio_features
# 16          0.040200    0.1120    0.563  137.990  audio_features
# 17          0.000000    0.1240    0.446  155.008  audio_features
# 18          0.000000    0.3180    0.137  202.006  audio_features
# 19          0.000000    0.0832    0.650  133.992  audio_features
# 20          0.000009    0.0936    0.533  136.041  audio_features
# 21          0.000000    0.1480    0.536   96.057  audio_features
# 22          0.000000    0.1110    0.434   93.023  audio_features
# 23          0.000000    0.0924    0.504   98.043  audio_features
# 24          0.000099    0.2060    0.633  151.979  audio_features
# 25          0.000000    0.1670    0.671  100.015  audio_features
# 26          0.000000    0.2420    0.534  102.211  audio_features
# 27          0.009860    0.2480    0.261  146.034  audio_features
# 28          0.000000    0.1200    0.366  125.107  audio_features
# 29          0.000000    0.3240    0.381  170.220  audio_features
# 30          0.000002    0.2220    0.347  102.998  audio_features
# 31          0.000000    0.1290    0.517  112.339  audio_features
# 32          0.000057    0.1990    0.111  104.014  audio_features
# 33          0.000000    0.3400    0.218   83.903  audio_features
# 34          0.000000    0.1830    0.742  150.024  audio_features
# 35          0.000000    0.1140    0.845  130.032  audio_features
# 36          0.000000    0.1100    0.219  130.003  audio_features
# 37          0.000000    0.3670    0.367  143.010  audio_features
# 38          0.000000    0.2000    0.329   89.949  audio_features
# 39          0.334000    0.1040    0.112   97.949  audio_features
# 40          0.000000    0.1360    0.374  145.028  audio_features
# 41          0.000000    0.0922    0.380  100.021  audio_features
# 42          0.003720    0.1230    0.473   75.023  audio_features
# 43          0.000080    0.1270    0.339  134.883  audio_features
# 44          0.000017    0.2380    0.638  109.004  audio_features
# 45          0.000000    0.2310    0.323   95.799  audio_features
# 46          0.000000    0.1080    0.233  160.075  audio_features
# 47          0.000000    0.1540    0.291  146.163  audio_features
# 48          0.000000    0.1510    0.506  191.971  audio_features
# 49          0.000000    0.2190    0.435  140.024  audio_features
#
#                         id  duration_ms  time_signature
# 0   6ocbgoVGwYJhOv1GgI9NsF       178627               4
# 1   4kV4N9D1iKVxx1KLvtTpjS       190440               4
# 2   2JvzF1RMd7lE3KmFlsyZD8       213594               4
# 3   6MWtB6iiXyIwun0YzU6DFP       149520               4
# 4   3KkXRkHbMCARz0aVfEt68P       158040               4
# 5   44ShclXTOOnYtt5CnCDeGV       240527               4
# 6   7eBqSVxrzQZtK2mmgRG6lC       268434               4
# 7   2IRZnDFmlqMuOrYOLnZZyc       180522               4
# 8   2t8yVaLvJ0RenpXUIAC52d       288624               4
# 9   3oh6SCCeLuXhFpEyepla6G       129264               4
# 10  3e9HZxeyfWwjeyPAMmWSSQ       207320               4
# 11  0rTV5WefWd1J3OwIheTzxM       197487               4
# 12  78QR3Wp35dqAhFEc2qAGjE       145543               4
# 13  4SPu0Ql902hTVXkBoNIYtq       182000               4
# 14  4NzMOnvSJVNKF7nw5NkXIP       193143               4
# 15  1TEL6MlSSVLSdhOSddidlJ       171573               4
# 16  7EQpvVujgytLVY8vKiDHAg       267107               4
# 17  2xLMifQCjDGFmkHkpNLD9h       312820               4
# 18  63cd4JkwGgYJrbOizbfmsp       194520               4
# 19  0PG9fbaaHFHfre2gUVo7AN       200890               4
# 20  5p7ujcrUXASCNwRaWNHR1C       201661               4
# 21  3Ol2xnObFdKV9pmRD2t9x8       179449               4
# 22  1wJRveJZLSb1rjhnUHQiv6       189487               4
# 23  0FZ4Dmg8jJJAPJnvBIzD9z       228760               4
# 24  2hloaUoRonYssMuqLCBLTX       216893               4
# 25  2dpaYNEQHiRxtZbfNsse99       214290               4
# 26  7COXchtUOMd6uIT6HvmRaI       162583               4
# 27  1xzBco0xcoJEDXktl7Jxrr       183907               4
# 28  39LmTF9RgyakzSYX8txrow       212267               3
# 29  3wFLWP0FcIqHK1wb1CPthQ       208880               4
# 30  6Qs4SXO9dwPj5GKvVOv8Ki       171030               4
# 31  2MJdgSby3DtSS7bUJx2cly       241440               4
# 32  4lD7gHKF1e8Y9stQuVezZB       271467               4
# 33  285pBltuF7vW8TeWk8hdRR       239836               4
# 34  14mHfNsSHN0FbLftyjrV9g       195637               4
# 35  5wujBwqG7INdStqGd4tRMX       169999               4
# 36  2GGMabyHXnJmjY6CXhhB2e       183527               4
# 37  2G1tXoGBaEMJ7FKGnkf6ud       203161               4
# 38  7FGq80cy8juXBCD2nrqdWU       170770               4
# 39  6zeeWid2sgw4lap2jV61PZ       229320               4
# 40  7dt6x5M1jzdTEt8oCbisTK       231267               4
# 41  79OEIr4J4FHV0O3KrhaXRb       177806               4
# 42  3ee8Jmje8o58CHK66QrVC2       166606               4
# 43  4T652DlATVHe0jdLKaN3Bw       222947               4
# 44  1fewSx2d5KIZ04wsooEBOz       203267               4
# 45  2VxeLyX666F8uXCJ0dZF8B       215733               4
# 46  4mGdjNMo0RonTlOEb7cYg4       239507               4
# 47  7e4KQkp5ZR1gXCAalRjX6B       201788               4
# 48  0jAfdqv18goRTUxm3ilRjb       192779               4
# 49  11cDEev79fPKi6uJCjUhu8       226747               4

# %%
#wanted to find a list of all playlists in the Top 50 Charts by Country category, but such category does not exist in the API.
#alternate resolution: manually copy and paste the playlist ids from spotify
#alternate resolution: instead of comparing data from all countries, we can analze the GLOBAL TOP 50 playlist vs GLOBAL VIRAL 50 playlist

url = f"https://api.spotify.com/v1/browse/categories/charts/playlists"
headers = {'authorization': f"Bearer {access_token}"}
response = requests.get(url, headers=headers)
cate= response.json()
pprint(cate)
# Out:
# {'error': {'message': "Specified id doesn't exist", 'status': 404}}

# %%
data.to_csv("top50us.csv", encoding='utf-8', index=False)
