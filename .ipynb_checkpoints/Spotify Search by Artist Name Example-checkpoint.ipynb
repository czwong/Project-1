# %%
###ARTIST EXAMPLE###
# artist_url = "https://api.spotify.com/v1/artists/"

# pprint(requests.get(artist_url + "66CXWjxzNUsdJxJ2JdwvnR", headers = token_headers).json())

# %%
###TRACKS EXAMPLE###
# track_url = "https://api.spotify.com/v1/tracks/"

# pprint(requests.get(track_url + "6ocbgoVGwYJhOv1GgI9NsF", headers = token_headers).json())

# %%
###PLAYLIST EXAMPLE###
# playlist_id = "37i9dQZEVXbLRQDuF5jeBp"

# pprint(requests.get(f"https://api.spotify.com/v1/playlists/{playlist_id}", headers = token_headers).json())

# %%
import requests
import spotipy
from requests.auth import HTTPBasicAuth
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint

# %%
from client import client_id, client_secret

# %%
top_artist_df = pd.read_csv("top2018.csv")
top_artist_df.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449    7    -9.211     1       0.1090        0.0332
# 1         0.740   0.613    8    -4.880     1       0.1450        0.2580
# 2         0.587   0.535    5    -6.090     0       0.0898        0.1170
# 3         0.739   0.559    8    -8.011     1       0.1170        0.5800
# 4         0.835   0.626    1    -5.833     1       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000083     0.552    0.357   77.169       198973               4
# 1          0.003720     0.123    0.473   75.023       166606               4
# 2          0.000066     0.131    0.140  159.847       218147               4
# 3          0.000000     0.112    0.439  140.124       221440               4
# 4          0.000060     0.396    0.350   91.030       217925               4

# %%
token_url = "https://accounts.spotify.com/api/token"
headers = {'content-type': 'application/x-www-form-urlencoded'}

token_params = {"grant_type" : "client_credentials"}

token_json = requests.post(token_url, params = token_params, headers = headers, auth = (client_id, client_secret)).json()
token = token_json['access_token']

token_json
# Out:
# {'access_token': 'BQARAgRQEaDhVvYZRn_iT6k_Yf8Dm1hMH3EyofZuRe0tQVIZjWkjd-MlxrVORn_WuT7pReoaIaFtGO8mF54',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
token_headers = {'authorization': f"Bearer {token}"}

artist_name_list = []
artist_id_list = []
artist_followers_list = []
genre_list = []
genre_popularity = []

search_url = "https://api.spotify.com/v1/search"

print("----------------------\nRetrieving Artist ID\n----------------------")

for artist in top_artist_df["artists"]:
    search_param = {"q" : artist,
                   "type" : "artist",
                   "limit" : 1}
    
    try:
        artist_json = requests.get(search_url, params = search_param, headers = token_headers).json()
        artist_id = artist_json["artists"]["items"][0]["id"]
        artist_name = artist_json["artists"]["items"][0]["name"]
        artist_follower = artist_json["artists"]["items"][0]["followers"]["total"]
        genres = artist_json["artists"]["items"][0]["genres"]
        
        if artist_id not in artist_id_list:
            artist_id_list.append(artist_id)
            artist_name_list.append(artist_name)
            artist_followers_list.append(artist_follower)
            
            for genre in genres:
                if genre not in genre_list:
                    genre_list.append(genre)
                    genre_popularity.append(1)
                    
                else:
                    genre_popularity[genre_list.index(genre)] += 1
                
            print(f"Artist ID Found | {artist_id} | {artist_name}")
            
        else:
            for genre in genres:
                genre_popularity[genre_list.index(genre)] += 1
                
            print("Artist ID in list already")
        
    except IndexError:
        print("Could Not Find Artist ID")
# Out:
# ----------------------
# Retrieving Artist ID
# ----------------------
# Artist ID Found | 3TVXtAsR1Inumwj472S9r4 | Drake
# Artist ID Found | 15UsOTVnJzReFVN1VCnxy4 | XXXTENTACION
# Artist ID Found | 246dkjvS1zLTtiykXe5h60 | Post Malone
# Artist ID in list already
# Artist ID in list already
# Artist ID in list already
# Artist ID Found | 4kYSro6naA4h99UJvo89HB | Cardi B
# Artist ID Found | 7CajNmpbOovFoOoasH2HaY | Calvin Harris
# Artist ID Found | 6M2wZ9GZgrQXHCFfjv46we | Dua Lipa
# Artist ID Found | 64KEffDW9EtZ1y2vBYgq8T | Marshmello
# Artist ID Found | 4nDoRrQiYLoBzwC5BhVJzF | Camila Cabello
# Artist ID Found | 4MCBfE4596Uoi2O4DtmEMz | Juice WRLD
# Artist ID in list already
# Artist ID Found | 04gDigrS5kc9YWfZHwBETP | Maroon 5
# Artist ID Found | 2qxJFvFYMEDqd7ui6kSAcq | Zedd
# Artist ID Found | 2YZyLoL8N0Wb9xBt1NhZWg | Kendrick Lamar
# Artist ID Found | 66CXWjxzNUsdJxJ2JdwvnR | Ariana Grande
# Artist ID Found | 1SupJlEpv7RS2tPNRaHViT | Nicky Jam
# Artist ID in list already
# Artist ID Found | 4TEJudQY2pXxVHPE3gD2EU | BlocBoy JB
# Artist ID Found | 4WN5naL3ofxrVBgFpguzKo | Rudimental
# Artist ID Found | 5hdhHgpxyniooUiQVaPxQ0 | Nio Garcia
# Artist ID Found | 4GvEc3ANtPPjt1ZJllr5Zl | Bazzi
# Artist ID Found | 5Rl15oVamLq7FbSb0NNBNy | 5 Seconds of Summer
# Artist ID in list already
# Artist ID Found | 6eUKZXaKkcviH0Ku9w2n3V | Ed Sheeran
# Artist ID Found | 6LuN9FCkKOj5PcnpouEgny | Khalid
# Artist ID Found | 64M6ah0SkkRsnPGtGiRAbb | Bebe Rexha
# Artist ID in list already
# Artist ID in list already
# Artist ID Found | 5LHRHt1k9lMyONurDHEdrp | Tyga
# Artist ID Found | 6MDME20pz9RveH9rEXvrOM | Clean Bandit
# Artist ID in list already
# Artist ID Found | 3EOEK57CV77D4ovYVcmiyt | Dennis Lloyd
# Artist ID Found | 4V8Sr092TqfHkfAA5fXXqG | Luis Fonsi
# Artist ID Found | 5CiGnKThu5ctn9pBxv7DGa | benny blanco
# Artist ID in list already
# Artist ID Found | 0C8ZW7ezQVs4URX5aX7Kqx | Selena Gomez
# Artist ID in list already
# Artist ID Found | 3v6Ji4uoWtKRkhuDUaxi9n | Dynoro
# Artist ID Found | 7dGJo4pcD2V6oG8kP0tJRR | Eminem
# Artist ID Found | 4VMYDCV2IEDYJArk749S6m | Daddy Yankee
# Artist ID Found | 0Y5tJX1MQlPlqiwlOH1tJY | Travis Scott
# Artist ID Found | 53XhwfbYqKCa1cC15pYq2q | Imagine Dragons
# Artist ID Found | 0vR2qb8m9WHeZ5ByCbimq2 | Reik
# Artist ID Found | 2o5jDhtHVPhrJdv3cEQ99Z | Tiësto
# Artist ID Found | 0du5cEVh5yTK9QJze8zA0C | Bruno Mars
# Artist ID in list already
# Artist ID Found | 6fOMl44jA4Sp5b9PpYCkzz | NF
# Artist ID Found | 1Xyo4u8uXC1ZmMpatF05PJ | The Weeknd
# Artist ID Found | 4DdkRBBYG6Yk9Ka8tdJ9BW | Offset
# Artist ID in list already
# Artist ID Found | 2wY79sveU1sp5g7SokKOiI | Sam Smith
# Artist ID Found | 1tqhsYv8yBBdwANFNzHtcr | Lil Dicky
# Artist ID in list already
# Artist ID Found | 7gZfnEnfiaHzxARJ2LeXrf | 6ix9ine
# Artist ID Found | 1HBjj22wzbscIZ9sEb5dyf | Jonas Blue
# Artist ID Found | 6t1gpxYbY8OlLA7D2RiikQ | Loud Luxury
# Artist ID Found | 4O15NlyKLIASxsJ0PrXPfz | Lil Uzi Vert
# Artist ID Found | 4obzFoKoKRHIphyHzJ35G3 | Becky G
# Artist ID Found | 1zNqDE7qDGCsyzJwohVaoX | Anne-Marie
# Artist ID in list already
# Artist ID in list already
# Artist ID Found | 7n2wHs1TKAczGzO7Dd2rGr | Shawn Mendes
# Artist ID in list already
# Artist ID in list already
# Artist ID Found | 4bw2Am3p9ji3mYsXNXtQcd | Piso 21
# Artist ID Found | 1Cs0zKBU1kc0i8ypK3B9ai | David Guetta
# Artist ID in list already
# Artist ID Found | 540vIaP2JwjQb9dm3aArA4 | DJ Snake
# Artist ID Found | 5p7f24Rk5HkUZsaS3BLG5F | Hailee Steinfeld
# Artist ID Found | 4kI8Ie27vjvonwaB2ePh8T | Portugal. The Man
# Artist ID in list already
# Artist ID Found | 6oMuImdp5ZcFhWP0ESe6mG | Migos
# Artist ID Found | 02kJSzxNuaWGqwubyUba0Z | G-Eazy
# Artist ID in list already
# Artist ID in list already
# Artist ID Found | 0haZhu4fFKt0Ag94kZDiz2 | Sofia Reyes
# Artist ID Found | 1GDbiv3spRmZ1XdM1jQbT7 | Natti Natasha
# Artist ID Found | 1pPmIToKXyGdsCF6LmqLmI | Rich The Kid
# Artist ID Found | 6qqNVTkY8uBg9cP3Jd7DAH | Billie Eilish
# Artist ID in list already
# Artist ID in list already
# Artist ID Found | 1i8SpTcr7yvPOmcqrbnVXY | Ozuna
# Artist ID in list already
# Artist ID Found | 1r4hJ1h58CWwUQe3MxPuau | Maluma
# Artist ID in list already
# Artist ID in list already
# Artist ID Found | 7FNnA9vBm6EKceENgCGRMb | Anitta
# Artist ID Found | 2OnKRchqP7tT0FzTvWIFI7 | Wolfine
# Artist ID in list already
# Artist ID Found | 5f7VJjfbwm532GiveGC0ZK | Lil Baby
# Artist ID Found | 5JZ7CnR6gTvEMKX4g70Amv | Lauv
# Artist ID Found | 7HV2RI2qNug4EcQqLbCAKS | Keala Settle
# Artist ID in list already
# Artist ID Found | 6U1dBXJhC8gXFjamvFTmHg | Zac Efron
# Artist ID in list already
# Artist ID Found | 0QHgL1lAIqAw0HtD7YldmP | DJ Khaled
# Artist ID Found | 5ZsFI1h6hIdQRw2ti0hz81 | ZAYN
# Artist ID Found | 3QSQFmccmX81fWCUSPTS7y | Dean Lewis

# %%
genre_popularity_df = pd.DataFrame({
    "Genre" : genre_list,
    "Genre Count" : genre_popularity
})

genre_popularity_df["Genre by Artist Percentage"] = (genre_popularity_df["Genre Count"]/len(artist_name_list)) * 100

genre_popularity_df = genre_popularity_df.sort_values(by = "Genre by Artist Percentage", ascending = False).head(15).reset_index()

genre_popularity_df
# Out:
#     index           Genre  Genre Count  Genre by Artist Percentage
# 0       7             pop           61                   87.142857
# 1       4             rap           29                   41.428571
# 2      12       dance pop           28                   40.000000
# 3      13   post-teen pop           21                   30.000000
# 4       3         pop rap           14                   20.000000
# 5       2         hip hop           13                   18.571429
# 6       8             edm           12                   17.142857
# 7      22  tropical house           11                   15.714286
# 8      30      trap music            9                   12.857143
# 9      25           latin            8                   11.428571
# 10     27       reggaeton            8                   11.428571
# 11      5         emo rap            7                   10.000000
# 12      6   miami hip hop            7                   10.000000
# 13      1    canadian pop            7                   10.000000
# 14     14          uk pop            6                    8.571429

# %%
fig, ax = plt.subplots(figsize = (40,15))
x_axis = np.arange(15)

ax.bar(x_axis, genre_popularity_df["Genre by Artist Percentage"])
plt.xticks(x_axis, genre_popularity_df["Genre"], Fontsize = 15)
plt.ylabel("Percentage of Artist Genre (%)", Fontsize = 20)
plt.title("Top 50 Artists by Genre 2018", Fontsize = 30)
plt.text(max(x_axis) + 1.3, 60, "Note:\nArtists may have multiple genres.", Fontsize = 20)

rects = ax.patches

for rect in rects:
    height = rect.get_height()
    width = rect.get_x() + 0.4
    if height > 0:
        ax.text(width, height, f'{round(height,2)}%', Fontsize = 20, ha = 'center', va = 'bottom')
    else:
         ax.text(width, height, f'{round(height,2)}%', Fontsize = 20, ha = 'center', va = 'top')

plt.show()
