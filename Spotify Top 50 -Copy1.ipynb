# %% [markdown]
# #### Notebook Setup

# %%
#import dependencies
import requests
from pprint import pprint
from requests.auth import HTTPBasicAuth
import pandas as pd

#authentication flow
client_id = "4b454f446d1f479082eec9de1c27a4a8"
client_secret = "e639450422594948b17c46d1a82f4882"

url = "https://accounts.spotify.com/api/token?grant_type=client_credentials"
headers = {'content-type': 'application/x-www-form-urlencoded'}

try:
   response = requests.post(url, headers=headers, auth=(client_id, client_secret))
   json = response.json()
   print(json)
   access_token = json["access_token"]
   print(access_token)
except:
   print("Something went wrong with the request")
# Out:
# {'access_token': 'BQAe-UK5HtisBP4puS1VuCkQwR4ypMYz37MIPyXTgZdllqhxgbqaMXJkSbWu5uIiLrtGUcZgovudKriDlb0', 'token_type': 'Bearer', 'expires_in': 3600, 'scope': ''}
# BQAe-UK5HtisBP4puS1VuCkQwR4ypMYz37MIPyXTgZdllqhxgbqaMXJkSbWu5uIiLrtGUcZgovudKriDlb0

# %% [markdown]
# #### Collect Data

# %%
topcountries = pd.read_excel("Top Country CSV/Top_50_by_Country.xlsm")
topcountries.head()
# Out:
#   Continents       Country                                        Spotify URL  \
# 0     Africa  South Africa  https://open.spotify.com/playlist/37i9dQZEVXbM...
# 1        NaN       Algeria  https://open.spotify.com/playlist/0fh0GGR82DYw...
# 2       Asia     Indonesia  https://open.spotify.com/playlist/37i9dQZEVXbO...
# 3        NaN         Japan  https://open.spotify.com/playlist/37i9dQZEVXbK...
# 4        NaN   Phillipines  https://open.spotify.com/playlist/37i9dQZEVXbN...
#
#       Spotify Playlist ID
# 0  37i9dQZEVXbMH2jvi6jvjk
# 1  0fh0GGR82DYwDuXLPk1AME
# 2  37i9dQZEVXbObFQZ3JLcXt
# 3  37i9dQZEVXbKXQ4mDTEBXq
# 4  37i9dQZEVXbNBz9cRCSFkY

# %%
playlists = topcountries["Spotify Playlist ID"]
playlists
# Out:
# 0     37i9dQZEVXbMH2jvi6jvjk
# 1     0fh0GGR82DYwDuXLPk1AME
# 2     37i9dQZEVXbObFQZ3JLcXt
# 3     37i9dQZEVXbKXQ4mDTEBXq
# 4     37i9dQZEVXbNBz9cRCSFkY
# 5     37i9dQZEVXbLnolsZ8PSNw
# 6     37i9dQZEVXbJiZcmkrIHGU
# 7     37i9dQZEVXbIPWwFssbupI
# 8     37i9dQZEVXbLRQDuF5jeBp
# 9     37i9dQZEVXbKj23U1GF4IR
# 10    37i9dQZEVXbMXbN3EUUhlg
# 11    37i9dQZEVXbOa2lmxNORXQ
# 12    37i9dQZEVXbMMy2roB9myp
# Name: Spotify Playlist ID, dtype: object

# %%
songs= jj['tracks']['items']
songs
# Out:
# [{'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2fYhqwDWXjbpjaIJPEfKFw'},
#     'href': 'https://api.spotify.com/v1/albums/2fYhqwDWXjbpjaIJPEfKFw',
#     'id': '2fYhqwDWXjbpjaIJPEfKFw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/8eaa3900ecd033ea52c72167f2a392b356b2b0a2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/d8443d0acece757484642e9a54e0f4367ae7cad0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ba570d71f798865789c65f3654d61bd54f7378e0',
#       'width': 64}],
#     'name': 'thank u, next',
#     'release_date': '2019-02-08',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2fYhqwDWXjbpjaIJPEfKFw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 178626,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM71900110'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ocbgoVGwYJhOv1GgI9NsF'},
#    'href': 'https://api.spotify.com/v1/tracks/6ocbgoVGwYJhOv1GgI9NsF',
#    'id': '6ocbgoVGwYJhOv1GgI9NsF',
#    'is_local': False,
#    'name': '7 rings',
#    'popularity': 92,
#    'preview_url': None,
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:6ocbgoVGwYJhOv1GgI9NsF'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2fYhqwDWXjbpjaIJPEfKFw'},
#     'href': 'https://api.spotify.com/v1/albums/2fYhqwDWXjbpjaIJPEfKFw',
#     'id': '2fYhqwDWXjbpjaIJPEfKFw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/8eaa3900ecd033ea52c72167f2a392b356b2b0a2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/d8443d0acece757484642e9a54e0f4367ae7cad0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ba570d71f798865789c65f3654d61bd54f7378e0',
#       'width': 64}],
#     'name': 'thank u, next',
#     'release_date': '2019-02-08',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2fYhqwDWXjbpjaIJPEfKFw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 190440,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM71900409'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4kV4N9D1iKVxx1KLvtTpjS'},
#    'href': 'https://api.spotify.com/v1/tracks/4kV4N9D1iKVxx1KLvtTpjS',
#    'id': '4kV4N9D1iKVxx1KLvtTpjS',
#    'is_local': False,
#    'name': "break up with your girlfriend, i'm bored",
#    'popularity': 97,
#    'preview_url': None,
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:4kV4N9D1iKVxx1KLvtTpjS'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#       'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#       'id': '6l3HvQ5sa6mXTsMTB19rO5',
#       'name': 'J. Cole',
#       'type': 'artist',
#       'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3XzSOIE6zGLliuqsVGLmUc'},
#     'href': 'https://api.spotify.com/v1/albums/3XzSOIE6zGLliuqsVGLmUc',
#     'id': '3XzSOIE6zGLliuqsVGLmUc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e46bc9cfa0f0e17f3869aa67dff235fa57b322f2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/8ffc55028e66802ede929ac7df9dbe942eb05fa1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/35f8510700d60712637e74a753c1cdf9a6a7b40e',
#       'width': 64}],
#     'name': 'MIDDLE CHILD',
#     'release_date': '2019-01-23',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3XzSOIE6zGLliuqsVGLmUc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#      'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#      'id': '6l3HvQ5sa6mXTsMTB19rO5',
#      'name': 'J. Cole',
#      'type': 'artist',
#      'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 213593,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QMJMT1902056'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2JvzF1RMd7lE3KmFlsyZD8'},
#    'href': 'https://api.spotify.com/v1/tracks/2JvzF1RMd7lE3KmFlsyZD8',
#    'id': '2JvzF1RMd7lE3KmFlsyZD8',
#    'is_local': False,
#    'name': 'MIDDLE CHILD',
#    'popularity': 95,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2JvzF1RMd7lE3KmFlsyZD8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5Dcz8PZHKuvTyjbqEPL5VM'},
#     'href': 'https://api.spotify.com/v1/albums/5Dcz8PZHKuvTyjbqEPL5VM',
#     'id': '5Dcz8PZHKuvTyjbqEPL5VM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/4a09059a2a756967588647bbcb5fd5f6fd8dd434',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/d8b52d52b2d0eb9070a1bff206bda1bd5834192e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/707bd27fc063d4ddbae323781e8bfd78885ff010',
#       'width': 64}],
#     'name': 'Wow.',
#     'release_date': '2018-12-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5Dcz8PZHKuvTyjbqEPL5VM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#      'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#      'id': '246dkjvS1zLTtiykXe5h60',
#      'name': 'Post Malone',
#      'type': 'artist',
#      'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 149520,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM71822626'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6MWtB6iiXyIwun0YzU6DFP'},
#    'href': 'https://api.spotify.com/v1/tracks/6MWtB6iiXyIwun0YzU6DFP',
#    'id': '6MWtB6iiXyIwun0YzU6DFP',
#    'is_local': False,
#    'name': 'Wow.',
#    'popularity': 98,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6MWtB6iiXyIwun0YzU6DFP'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3pOj4mmxL5MUwR1IR8LPzL'},
#     'href': 'https://api.spotify.com/v1/albums/3pOj4mmxL5MUwR1IR8LPzL',
#     'id': '3pOj4mmxL5MUwR1IR8LPzL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e5b0d120fd72dedb1b2296e6088b1ee75faf255b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/1041e437abc090e858bc6160e656bdcc79beb532',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/e8e114706d84def71dd0920897c4580eabb701b2',
#       'width': 64}],
#     'name': 'Spider-Man: Into the Spider-Verse (Deluxe Edition / Soundtrack From & Inspired By The Motion Picture)',
#     'release_date': '2019-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:3pOj4mmxL5MUwR1IR8LPzL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#      'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#      'id': '246dkjvS1zLTtiykXe5h60',
#      'name': 'Post Malone',
#      'type': 'artist',
#      'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#      'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#      'id': '1zNqQNIdeOUZHb8zbZRFMX',
#      'name': 'Swae Lee',
#      'type': 'artist',
#      'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 158040,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71814888'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7dbka99KTWke5o9hRp0JoB'},
#    'href': 'https://api.spotify.com/v1/tracks/7dbka99KTWke5o9hRp0JoB',
#    'id': '7dbka99KTWke5o9hRp0JoB',
#    'is_local': False,
#    'name': 'Sunflower - Spider-Man: Into the Spider-Verse',
#    'popularity': 66,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7dbka99KTWke5o9hRp0JoB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#       'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#       'id': '4VIvfOurcf0vuLRxLkGnIG',
#       'name': 'Bradley Cooper',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4sLtOBOzn4s3GDUv3c5oJD'},
#     'href': 'https://api.spotify.com/v1/albums/4sLtOBOzn4s3GDUv3c5oJD',
#     'id': '4sLtOBOzn4s3GDUv3c5oJD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c58764827434c5471f944b0700ab98fd3d0bd5a7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/a4964b89670463b5d0ced3e77c6b80f82a413329',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/67c3676980675070996bef906389dd4821916d6f',
#       'width': 64}],
#     'name': 'A Star Is Born Soundtrack',
#     'release_date': '2018-10-05',
#     'release_date_precision': 'day',
#     'total_tracks': 34,
#     'type': 'album',
#     'uri': 'spotify:album:4sLtOBOzn4s3GDUv3c5oJD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 215733,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71813192'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2VxeLyX666F8uXCJ0dZF8B'},
#    'href': 'https://api.spotify.com/v1/tracks/2VxeLyX666F8uXCJ0dZF8B',
#    'id': '2VxeLyX666F8uXCJ0dZF8B',
#    'is_local': False,
#    'name': 'Shallow',
#    'popularity': 92,
#    'preview_url': None,
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:2VxeLyX666F8uXCJ0dZF8B'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cNDP5yjU5vjeR8qMf4grg'},
#       'href': 'https://api.spotify.com/v1/artists/1cNDP5yjU5vjeR8qMf4grg',
#       'id': '1cNDP5yjU5vjeR8qMf4grg',
#       'name': 'YNW Melly',
#       'type': 'artist',
#       'uri': 'spotify:artist:1cNDP5yjU5vjeR8qMf4grg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7naY6j4wcgUxfHB98G79CW'},
#     'href': 'https://api.spotify.com/v1/albums/7naY6j4wcgUxfHB98G79CW',
#     'id': '7naY6j4wcgUxfHB98G79CW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b2be804a976693136edae3fbd7e52a0d37791f00',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/a3a96e75e50db39157cc39753064c1dd66cc08e9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/67163fc31f0234842014c98c24e3b7c63f5c377f',
#       'width': 64}],
#     'name': 'I AM YOU',
#     'release_date': '2018-08-03',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:7naY6j4wcgUxfHB98G79CW'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cNDP5yjU5vjeR8qMf4grg'},
#      'href': 'https://api.spotify.com/v1/artists/1cNDP5yjU5vjeR8qMf4grg',
#      'id': '1cNDP5yjU5vjeR8qMf4grg',
#      'name': 'YNW Melly',
#      'type': 'artist',
#      'uri': 'spotify:artist:1cNDP5yjU5vjeR8qMf4grg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 268434,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QMCE31801827'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7eBqSVxrzQZtK2mmgRG6lC'},
#    'href': 'https://api.spotify.com/v1/tracks/7eBqSVxrzQZtK2mmgRG6lC',
#    'id': '7eBqSVxrzQZtK2mmgRG6lC',
#    'is_local': False,
#    'name': 'Murder On My Mind',
#    'popularity': 88,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b681a45cf2f796326f42bed43a6e419cd88ef92c?cid=4b454f446d1f479082eec9de1c27a4a8',
#    'track': True,
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:7eBqSVxrzQZtK2mmgRG6lC'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#       'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#       'id': '4MCBfE4596Uoi2O4DtmEMz',
#       'name': 'Juice WRLD',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4wTEUOUuqBaKdExtQdYKfz'},
#     'href': 'https://api.spotify.com/v1/albums/4wTEUOUuqBaKdExtQdYKfz',
#     'id': '4wTEUOUuqBaKdExtQdYKfz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/3edba2ba0e95689e9eddb21ea2617cd35c0143a5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/79fd97a433974cdffbde9504abd7742154340c8d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/8da25f996eeafecf905c5a357df5eae0850123b9',
#       'width': 64}],
#     'name': 'Robbery',
#     'release_date': '2019-02-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4wTEUOUuqBaKdExtQdYKfz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#      'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#      'id': '4MCBfE4596Uoi2O4DtmEMz',
#      'name': 'Juice WRLD',
#      'type': 'artist',
#      'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 240527,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG11900302'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/44ShclXTOOnYtt5CnCDeGV'},
#    'href': 'https://api.spotify.com/v1/tracks/44ShclXTOOnYtt5CnCDeGV',
#    'id': '44ShclXTOOnYtt5CnCDeGV',
#    'is_local': False,
#    'name': 'Robbery',
#    'popularity': 84,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:44ShclXTOOnYtt5CnCDeGV'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20sxb77xiYeusSH8cVdatc'},
#       'href': 'https://api.spotify.com/v1/artists/20sxb77xiYeusSH8cVdatc',
#       'id': '20sxb77xiYeusSH8cVdatc',
#       'name': 'Meek Mill',
#       'type': 'artist',
#       'uri': 'spotify:artist:20sxb77xiYeusSH8cVdatc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6UYZEYjpN1DYRW0kqFy9ZE'},
#     'href': 'https://api.spotify.com/v1/albums/6UYZEYjpN1DYRW0kqFy9ZE',
#     'id': '6UYZEYjpN1DYRW0kqFy9ZE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/77eb7c17cafe5503c5866117e0a3e5fc94620101',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/77eb7c17cafe5502425b0163fbf6d9d57e571394',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/77eb7c17cafe55011ca486503ede31e995e12385',
#       'width': 64}],
#     'name': 'Championships',
#     'release_date': '2018-11-30',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:6UYZEYjpN1DYRW0kqFy9ZE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20sxb77xiYeusSH8cVdatc'},
#      'href': 'https://api.spotify.com/v1/artists/20sxb77xiYeusSH8cVdatc',
#      'id': '20sxb77xiYeusSH8cVdatc',
#      'name': 'Meek Mill',
#      'type': 'artist',
#      'uri': 'spotify:artist:20sxb77xiYeusSH8cVdatc'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 180522,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT21812710'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2IRZnDFmlqMuOrYOLnZZyc'},
#    'href': 'https://api.spotify.com/v1/tracks/2IRZnDFmlqMuOrYOLnZZyc',
#    'id': '2IRZnDFmlqMuOrYOLnZZyc',
#    'is_local': False,
#    'name': 'Going Bad (feat. Drake)',
#    'popularity': 94,
#    'preview_url': 'https://p.scdn.co/mp3-preview/29e19c68dd853994221a90103db28427f1185e33?cid=4b454f446d1f479082eec9de1c27a4a8',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:2IRZnDFmlqMuOrYOLnZZyc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/007DWn799UWvfY1wwZeENR'},
#     'href': 'https://api.spotify.com/v1/albums/007DWn799UWvfY1wwZeENR',
#     'id': '007DWn799UWvfY1wwZeENR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e89fed2244d8ea00f46312790c3a3b9f4092e5a6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5b845dfbc719f44f0fa796c53c2adefe8559238b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/57e978c51570dbb7990c69c7826ec3a5ee340057',
#       'width': 64}],
#     'name': 'i am > i was',
#     'release_date': '2018-12-21',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:007DWn799UWvfY1wwZeENR'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#      'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#      'id': '1URnnhqYAYcrqrcwql10ft',
#      'name': '21 Savage',
#      'type': 'artist',
#      'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 288624,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZ45A1700126'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2t8yVaLvJ0RenpXUIAC52d'},
#    'href': 'https://api.spotify.com/v1/tracks/2t8yVaLvJ0RenpXUIAC52d',
#    'id': '2t8yVaLvJ0RenpXUIAC52d',
#    'is_local': False,
#    'name': 'a lot',
#    'popularity': 92,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0ff1fadf009e81e7d80912c2372c7381a49e5863?cid=4b454f446d1f479082eec9de1c27a4a8',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2t8yVaLvJ0RenpXUIAC52d'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fl1V19tmjt57oBdxXKAjJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Fl1V19tmjt57oBdxXKAjJ',
#       'id': '3Fl1V19tmjt57oBdxXKAjJ',
#       'name': 'Blueface',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Fl1V19tmjt57oBdxXKAjJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2gZmrByp6yiyePHi3dzZ1d'},
#     'href': 'https://api.spotify.com/v1/albums/2gZmrByp6yiyePHi3dzZ1d',
#     'id': '2gZmrByp6yiyePHi3dzZ1d',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/083303ee703e5501ca36185592360e33157ce396',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/590ec298fdf16fd91501dcbebc0836c750ea2d01',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/cb7d1c7de74a9610a6863286219e9aa7fea5f8a6',
#       'width': 64}],
#     'name': 'Famous Cryp',
#     'release_date': '2018-12-18',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2gZmrByp6yiyePHi3dzZ1d'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fl1V19tmjt57oBdxXKAjJ'},
#      'href': 'https://api.spotify.com/v1/artists/3Fl1V19tmjt57oBdxXKAjJ',
#      'id': '3Fl1V19tmjt57oBdxXKAjJ',
#      'name': 'Blueface',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Fl1V19tmjt57oBdxXKAjJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 129264,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZDA51839408'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3oh6SCCeLuXhFpEyepla6G'},
#    'href': 'https://api.spotify.com/v1/tracks/3oh6SCCeLuXhFpEyepla6G',
#    'id': '3oh6SCCeLuXhFpEyepla6G',
#    'is_local': False,
#    'name': 'Thotiana',
#    'popularity': 91,
#    'preview_url': 'https://p.scdn.co/mp3-preview/86190aba97b38d4906c5312cad98263f26fbd0a5?cid=4b454f446d1f479082eec9de1c27a4a8',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3oh6SCCeLuXhFpEyepla6G'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2fYhqwDWXjbpjaIJPEfKFw'},
#     'href': 'https://api.spotify.com/v1/albums/2fYhqwDWXjbpjaIJPEfKFw',
#     'id': '2fYhqwDWXjbpjaIJPEfKFw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/8eaa3900ecd033ea52c72167f2a392b356b2b0a2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/d8443d0acece757484642e9a54e0f4367ae7cad0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ba570d71f798865789c65f3654d61bd54f7378e0',
#       'width': 64}],
# ...
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 177806,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM71820721'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/79OEIr4J4FHV0O3KrhaXRb'},
#    'href': 'https://api.spotify.com/v1/tracks/79OEIr4J4FHV0O3KrhaXRb',
#    'id': '79OEIr4J4FHV0O3KrhaXRb',
#    'is_local': False,
#    'name': 'Splashin',
#    'popularity': 87,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:79OEIr4J4FHV0O3KrhaXRb'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'available_markets': ['AE',
#      'BH',
#      'CA',
#      'DZ',
#      'EG',
#      'GB',
#      'ID',
#      'IE',
#      'IN',
#      'JO',
#      'KW',
#      'LB',
#      'MA',
#      'MX',
#      'MY',
#      'OM',
#      'PS',
#      'QA',
#      'SA',
#      'SG',
#      'TN',
#      'TR',
#      'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6sUzNE1SPNLBXBCZs3PIAO'},
#     'href': 'https://api.spotify.com/v1/albums/6sUzNE1SPNLBXBCZs3PIAO',
#     'id': '6sUzNE1SPNLBXBCZs3PIAO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/065c3e629701f49c7d8f3146763eb4f53b680b29',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/e07b7ce8591b8a8ee2266b765de0f944c995fd3e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/556127045b302819df6dbafd756c388fb25695a4',
#       'width': 64}],
#     'name': 'thank u, next',
#     'release_date': '2018-02-07',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6sUzNE1SPNLBXBCZs3PIAO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'available_markets': ['AE',
#     'BH',
#     'CA',
#     'DZ',
#     'EG',
#     'GB',
#     'ID',
#     'IE',
#     'IN',
#     'JO',
#     'KW',
#     'LB',
#     'MA',
#     'MX',
#     'MY',
#     'OM',
#     'PS',
#     'QA',
#     'SA',
#     'SG',
#     'TN',
#     'TR',
#     'US'],
#    'disc_number': 1,
#    'duration_ms': 271466,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71900406'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4lD7gHKF1e8Y9stQuVezZB'},
#    'href': 'https://api.spotify.com/v1/tracks/4lD7gHKF1e8Y9stQuVezZB',
#    'id': '4lD7gHKF1e8Y9stQuVezZB',
#    'is_local': False,
#    'name': 'ghostin',
#    'popularity': 67,
#    'preview_url': None,
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:4lD7gHKF1e8Y9stQuVezZB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2hlmm7s2ICUX0LVIhVFlZQ'},
#       'href': 'https://api.spotify.com/v1/artists/2hlmm7s2ICUX0LVIhVFlZQ',
#       'id': '2hlmm7s2ICUX0LVIhVFlZQ',
#       'name': 'Gunna',
#       'type': 'artist',
#       'uri': 'spotify:artist:2hlmm7s2ICUX0LVIhVFlZQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1oUzjom2A9xtyRM1SdOAGj'},
#     'href': 'https://api.spotify.com/v1/albums/1oUzjom2A9xtyRM1SdOAGj',
#     'id': '1oUzjom2A9xtyRM1SdOAGj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0a9c863f9cf689848f120b0ed7caddf29989eda2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/bd11a941c29bea2edb906e38408d99824148bcbf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/31a7e99c2b13d8b82a8ee189e2319469a3724ed1',
#       'width': 64}],
#     'name': 'Drip or Drown 2',
#     'release_date': '2019-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:1oUzjom2A9xtyRM1SdOAGj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2hlmm7s2ICUX0LVIhVFlZQ'},
#      'href': 'https://api.spotify.com/v1/artists/2hlmm7s2ICUX0LVIhVFlZQ',
#      'id': '2hlmm7s2ICUX0LVIhVFlZQ',
#      'name': 'Gunna',
#      'type': 'artist',
#      'uri': 'spotify:artist:2hlmm7s2ICUX0LVIhVFlZQ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 180780,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QMCE31902017'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/76PwajqH3ej4hnk9tgaJpp'},
#    'href': 'https://api.spotify.com/v1/tracks/76PwajqH3ej4hnk9tgaJpp',
#    'id': '76PwajqH3ej4hnk9tgaJpp',
#    'is_local': False,
#    'name': 'Outstanding',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cbefc9f948a804976e58b51007b222d649331d15?cid=4b454f446d1f479082eec9de1c27a4a8',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:76PwajqH3ej4hnk9tgaJpp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#       'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#       'id': '6LuN9FCkKOj5PcnpouEgny',
#       'name': 'Khalid',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#     'available_markets': ['AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Qxc2NJ7yPKVFRWi3llRr2'},
#     'href': 'https://api.spotify.com/v1/albums/2Qxc2NJ7yPKVFRWi3llRr2',
#     'id': '2Qxc2NJ7yPKVFRWi3llRr2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/745289626882a42ef6e89ccc2ea06110518fb23c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/9bd48984cf147520fd842e7d85e3f5c0169cf213',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/d5a8fba6c0f5f8e1ce4dbc4e8200a4baaa8e272c',
#       'width': 64}],
#     'name': 'Suncity',
#     'release_date': '2018-10-18',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:2Qxc2NJ7yPKVFRWi3llRr2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#      'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#      'id': '6LuN9FCkKOj5PcnpouEgny',
#      'name': 'Khalid',
#      'type': 'artist',
#      'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#    'available_markets': ['AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 210666,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC11803517'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5kfNriitmkNE8mUbZ7gbq8'},
#    'href': 'https://api.spotify.com/v1/tracks/5kfNriitmkNE8mUbZ7gbq8',
#    'id': '5kfNriitmkNE8mUbZ7gbq8',
#    'is_local': False,
#    'name': 'Saturday Nights',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8c9de7d1a1da28f8e1da8bad0c7ce58f97da9f71?cid=4b454f446d1f479082eec9de1c27a4a8',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:5kfNriitmkNE8mUbZ7gbq8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'},
#       'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#       'id': '15UsOTVnJzReFVN1VCnxy4',
#       'name': 'XXXTENTACION',
#       'type': 'artist',
#       'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Ti79nwTsont5ZHfdxIzAm'},
#     'href': 'https://api.spotify.com/v1/albums/2Ti79nwTsont5ZHfdxIzAm',
#     'id': '2Ti79nwTsont5ZHfdxIzAm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/2e70e7b198acc3bb03aaba9424c5fb23fb38c536',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4b180600c11e3c89c8b16d6aea3590a5cbfdaea9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/6924e7074859f79464dd8ddf48455c181df4ce1b',
#       'width': 64}],
#     'name': '?',
#     'release_date': '2018-03-16',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:2Ti79nwTsont5ZHfdxIzAm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'},
#      'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#      'id': '15UsOTVnJzReFVN1VCnxy4',
#      'name': 'XXXTENTACION',
#      'type': 'artist',
#      'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 135090,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG11800209'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0JP9xo3adEtGSdUEISiszL'},
#    'href': 'https://api.spotify.com/v1/tracks/0JP9xo3adEtGSdUEISiszL',
#    'id': '0JP9xo3adEtGSdUEISiszL',
#    'is_local': False,
#    'name': 'Moonlight',
#    'popularity': 90,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:0JP9xo3adEtGSdUEISiszL'},
#   'video_thumbnail': {'url': None}}]

# %%
url = f"https://api.spotify.com/v1/playlists/{playlist}"
headers = {'authorization': f"Bearer {access_token}"}

for playlist in playlists:
    # https://api.spotify.com/v1/artists/{id}
    #This is for US Top 50 playlist
    #playlist_id = "37i9dQZEVXbLRQDuF5jeBp"aus= "37i9dQZEVXbJPcfkRz0wJ0"
    #spotify:user:spotifycharts:playlist:37i9dQZEVXbLRQDuF5jeBp

    response = requests.get(url, headers=headers)

    #pprint(response.json())
    #print(json.dumps(newrelease, sort_keys=True, indent=4))
    jj = response.json()
    #pprint(jj)
    ids = []
    artists = []
    tracks = []
    releasedate = []
    audiofeatures = []
    popularity = []
    artid = []
    genre = []
    
    
    for x in songs:
        idsong = x["track"]["id"]
        ids.append(idsong)
        
        artist = x['track']['album']['artists'][0]['name']
        artists.append(artist)
        
        track = x['track']['name']
        tracks.append(track)
        
        rd = x["track"]["album"]["release_date"]
        releasedate.append(rd)
        
        poppin = x['track']['popularity']
        popularity.append(poppin)
        
        url = f"https://api.spotify.com/v1/audio-features/{idsong}"

        response = requests.get(url, headers=headers)
        
        features= response.json()
        
        audiofeatures.append(features)
        
        ida = x['track']['album']['artists'][0]["uri"][15:]
        artid.append(ida)
        
        url = f"https://api.spotify.com/v1/artists/{ida}"

        response = requests.get(url, headers=headers)
        gen = response.json()
        genr = gen["genres"]
        genre.append(genr)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-7021f8d56362> in <module>()
#      55         response = requests.get(url, headers=headers)
#      56         gen = response.json()
# ---> 57         genr = gen["genres"]
#      58         genre.append(genr)
#
# KeyError: 'genres'

# %%
#test check: to grab album uri
#jj['tracks']['items'][0]['track']['album']['uri'][14:])
#test check to grab artist uri
pprint(jj['tracks']['items'][0]['track']['album']['artists'][0]["uri"][15:])
# Out:
# '66CXWjxzNUsdJxJ2JdwvnR'

# %%
songs= jj['tracks']['items']

# %%
#Create lists for relevant data & then organize into a dataframe
ids = []
artists = []
tracks = []
releasedate = []
audiofeatures = []
popularity = []
for x in songs:
    idsong = x["track"]["id"]
    ids.append(idsong)
    artist = x['track']['album']['artists'][0]['name']
    artists.append(artist)
    track = x['track']['name']
    tracks.append(track)
    rd = x["track"]["album"]["release_date"]
    releasedate.append(rd)
    poppin = x['track']['popularity']
    popularity.append(poppin)
    url = f"https://api.spotify.com/v1/audio-features/{idsong}"
    headers = {'authorization': f"Bearer {access_token}"}
    response = requests.get(url, headers=headers)
    features= response.json()
    audiofeatures.append(features)
#pprint(features)

# %%
#looking for genre of each artist via for loop
artid = []
genre = []
for x in songs:
    ida = x['track']['album']['artists'][0]["uri"][15:]
    artid.append(ida)
    url = f"https://api.spotify.com/v1/artists/{ida}"
    headers = {'authorization': f"Bearer {access_token}"}
    response = requests.get(url, headers=headers)
    gen= response.json()
    genr = gen["genres"]
    genre.append(genr)
    
print(len(genre))
# Out:
# 50

# %%
pprint(gen)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'},
#  'followers': {'href': None, 'total': 11027672},
#  'genres': ['emo rap', 'miami hip hop'],
#  'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4',
#  'id': '15UsOTVnJzReFVN1VCnxy4',
#  'images': [{'height': 640,
#              'url': 'https://i.scdn.co/image/80eeb2600b7b7eddbef44bcc1fbc87aac9ab2e59',
#              'width': 640},
#             {'height': 320,
#              'url': 'https://i.scdn.co/image/3aae68e363871095051f421dff0203cb9084805b',
#              'width': 320},
#             {'height': 160,
#              'url': 'https://i.scdn.co/image/b296f763e7f305e51ce70da0955f290b3c038b6b',
#              'width': 160}],
#  'name': 'XXXTENTACION',
#  'popularity': 95,
#  'type': 'artist',
#  'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}

# %%
#separate the dictionary into lists
afkeys = [list(x.keys()) for x in audiofeatures]
afvalues = [list(x.values()) for x in audiofeatures]

#create a dataframe for audio features
af = pd.DataFrame(afvalues, columns=afkeys[0])
#create a dataframe for track info
tdata = pd.DataFrame(list(zip(artists, artid, tracks, ids, releasedate, popularity, genre)),columns=["artists", "artist id", "tracks", "track ids", "released", "popularity", "genre"])

# %%
tdata.head()
# Out:
#            artists               artist id  \
# 0    Ariana Grande  66CXWjxzNUsdJxJ2JdwvnR
# 1    Ariana Grande  66CXWjxzNUsdJxJ2JdwvnR
# 2          J. Cole  6l3HvQ5sa6mXTsMTB19rO5
# 3      Post Malone  246dkjvS1zLTtiykXe5h60
# 4  Various Artists  0LyfQWJT6nXafLPZqxe9Of
#
#                                           tracks               track ids  \
# 0                                        7 rings  6ocbgoVGwYJhOv1GgI9NsF
# 1       break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 2                                   MIDDLE CHILD  2JvzF1RMd7lE3KmFlsyZD8
# 3                                           Wow.  6MWtB6iiXyIwun0YzU6DFP
# 4  Sunflower - Spider-Man: Into the Spider-Verse  7dbka99KTWke5o9hRp0JoB
#
#      released  popularity                                          genre
# 0  2019-02-08          92                [dance pop, pop, post-teen pop]
# 1  2019-02-08          97                [dance pop, pop, post-teen pop]
# 2  2019-01-23          95  [conscious hip hop, nc hip hop, pop rap, rap]
# 3  2018-12-24          98                                     [pop, rap]
# 4  2019-02-22          66                                             []

# %%
#combine the two dataframes 
data = pd.concat([tdata, af], axis=1, sort=False)

#clean data by removing unneccesary columns
data.drop(["uri", "track_href", "analysis_url", "id"],axis = 1, inplace = True)
data.head()
# Out:
#            artists               artist id  \
# 0    Ariana Grande  66CXWjxzNUsdJxJ2JdwvnR
# 1    Ariana Grande  66CXWjxzNUsdJxJ2JdwvnR
# 2          J. Cole  6l3HvQ5sa6mXTsMTB19rO5
# 3      Post Malone  246dkjvS1zLTtiykXe5h60
# 4  Various Artists  0LyfQWJT6nXafLPZqxe9Of
#
#                                           tracks               track ids  \
# 0                                        7 rings  6ocbgoVGwYJhOv1GgI9NsF
# 1       break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 2                                   MIDDLE CHILD  2JvzF1RMd7lE3KmFlsyZD8
# 3                                           Wow.  6MWtB6iiXyIwun0YzU6DFP
# 4  Sunflower - Spider-Man: Into the Spider-Verse  7dbka99KTWke5o9hRp0JoB
#
#      released  popularity                                          genre  \
# 0  2019-02-08          92                [dance pop, pop, post-teen pop]
# 1  2019-02-08          97                [dance pop, pop, post-teen pop]
# 2  2019-01-23          95  [conscious hip hop, nc hip hop, pop rap, rap]
# 3  2018-12-24          98                                     [pop, rap]
# 4  2019-02-22          66                                             []
#
#    danceability  energy  key       ...        mode  speechiness  acousticness  \
# 0         0.771   0.320    1       ...           0       0.3160        0.6010
# 1         0.726   0.545    5       ...           0       0.1020        0.0378
# 2         0.837   0.364    8       ...           1       0.2760        0.1490
# 3         0.833   0.539   11       ...           0       0.1780        0.1630
# 4         0.761   0.479    2       ...           1       0.0466        0.5520
#
#    instrumentalness  liveness  valence    tempo            type duration_ms  \
# 0          0.000000    0.0885    0.312  139.844  audio_features      178627
# 1          0.000000    0.1080    0.348  169.991  audio_features      190440
# 2          0.000000    0.2710    0.463  123.984  audio_features      213594
# 3          0.000002    0.1010    0.385   99.947  audio_features      149520
# 4          0.000000    0.0704    0.912   89.913  audio_features      158040
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 21 columns]

# %%
#wanted to find a list of all playlists in the Top 50 Charts by Country category, but such category does not exist in the API.
#alternate resolution: manually copy and paste the playlist ids from spotify
#alternate resolution: instead of comparing data from all countries, we can analze the GLOBAL TOP 50 playlist vs GLOBAL VIRAL 50 playlist

url = f"https://api.spotify.com/v1/browse/categories/charts/playlists"
headers = {'authorization': f"Bearer {access_token}"}
response = requests.get(url, headers=headers)
cate= response.json()
pprint(cate)
# Out:
# {'error': {'message': "Specified id doesn't exist", 'status': 404}}

# %%
#data.to_csv("top50us.csv", encoding='utf-8', index=False)

# %% [markdown]
# #### Statistics Summary

# %%
data.describe()
# Out:
#        popularity  danceability     energy       key   loudness       mode  \
# count   50.000000     50.000000  50.000000  50.00000  50.000000  50.000000
# mean    86.980000      0.745520   0.557760   5.56000  -6.926800   0.620000
# std      8.582112      0.125958   0.122978   3.50603   2.305502   0.490314
# min     66.000000      0.448000   0.314000   0.00000 -14.505000   0.000000
# 25%     84.500000      0.665750   0.475250   2.00000  -8.015750   0.000000
# 50%     90.000000      0.749500   0.564500   6.00000  -6.706500   1.000000
# 75%     92.000000      0.837000   0.656000   8.00000  -5.292000   1.000000
# max     98.000000      0.950000   0.792000  11.00000  -2.749000   1.000000
#
#        speechiness  acousticness  instrumentalness   liveness    valence  \
# count    50.000000     50.000000         50.000000  50.000000  50.000000
# mean      0.155998      0.266033          0.011106   0.172108   0.425760
# std       0.119164      0.205255          0.052173   0.096829   0.181713
# min       0.027400      0.001950          0.000000   0.070400   0.111000
# 25%       0.066675      0.083125          0.000000   0.106500   0.325250
# 50%       0.100250      0.217000          0.000000   0.126000   0.380500
# 75%       0.242500      0.387500          0.000003   0.222000   0.534750
# max       0.565000      0.787000          0.334000   0.552000   0.912000
#
#             tempo    duration_ms  time_signature
# count   50.000000      50.000000       50.000000
# mean   121.384420  202788.740000        3.980000
# std     28.684726   38350.040776        0.141421
# min     74.972000  129264.000000        3.000000
# 25%     98.519000  178832.500000        4.000000
# 50%    122.015000  199188.500000        4.000000
# 75%    144.523500  225793.250000        4.000000
# max    202.006000  312820.000000        4.000000

# %% [markdown]
# #### Charts
